# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    # conv2d computes a a 2D convolution given
    # - a 4D input tensor (our data)
    # - a 4D filter tensor (our weights)
    # - strides: 1D tensor of length 4
    # - padding
    # This is flattened to a 2D matrix of shape
    # [filter_height * filter_width * in_channels, output_channels]
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.041924
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.062698
# Minibatch accuracy: 18.8%
# Validation accuracy: 23.8%
# Minibatch loss at step 100: 1.189715
# Minibatch accuracy: 56.2%
# Validation accuracy: 65.2%
# Minibatch loss at step 150: 0.560170
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.3%
# Minibatch loss at step 200: 1.008396
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.1%
# Minibatch loss at step 250: 1.248108
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 300: 0.311837
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 350: 0.532968
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 400: 0.223962
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 450: 0.951198
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.0%
# Minibatch loss at step 500: 0.568726
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 550: 0.822356
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 600: 0.296136
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 650: 0.973090
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.4%
# Minibatch loss at step 700: 0.928896
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 750: 0.068852
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 800: 0.606289
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 850: 0.801289
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 900: 0.573223
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 950: 0.537840
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 1000: 0.335549
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Test accuracy: 89.6%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  
    def maxpool2d(x, k):
        return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')

    # Model.
    def model(data):
        # conv2d computes a a 2D convolution given
        # - a 4D input tensor (our data)
        # - a 4D filter tensor (our weights)
        # - strides: 1D tensor of length 4
        # - padding
        # This is flattened to a 2D matrix of shape
        # [filter_height * filter_width * in_channels, output_channels]
        conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        bias1 = tf.nn.relu(conv1 + layer1_biases)
        # Let's maxpool to downsample
        pool1 = maxpool2d(bias1, k=2)
     
        conv2 = tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME')
        bias2 = tf.nn.relu(conv2 + layer2_biases)
        pool2 = maxpool2d(bias2, k=2)
    
        # Fully connected layer, we need to reshape our convolution layer output
        # to fit the fully connected layer input
        shape = pool2.get_shape().as_list()
        reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    
        # Output layer
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.262327
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.755030
# Minibatch accuracy: 18.8%
# Validation accuracy: 39.7%
# Minibatch loss at step 100: 1.274468
# Minibatch accuracy: 62.5%
# Validation accuracy: 51.9%
# Minibatch loss at step 150: 0.555031
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.1%
# Minibatch loss at step 200: 1.113222
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.9%
# Minibatch loss at step 250: 1.047670
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.6%
# Minibatch loss at step 300: 0.411903
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 350: 0.438665
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 400: 0.194973
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 450: 0.952879
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 500: 0.677778
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.8%
# Minibatch loss at step 550: 0.859821
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 600: 0.325066
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 650: 0.756195
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 700: 0.853237
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 750: 0.053291
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 800: 0.528602
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 850: 0.821167
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 900: 0.671657
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 950: 0.652932
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 1000: 0.321773
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.5%
# Test accuracy: 91.0%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 32
patch_size = 4
depth = 16
num_hidden = 256
num_hidden2 = 128

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_hidden2], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden2]))
    layer5_weights = tf.Variable(tf.truncated_normal(
        [num_hidden2, num_labels], stddev=0.1))
    layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
    
    
    def conv2d(x, k, w, b):
        conv = tf.nn.conv2d(x, w, [1, k, k, 1], padding='SAME')
        return tf.nn.relu(conv + b)

    def maxpool2d(x, k):
        return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')

    # Model.
    def model(data, apply_dropout=True):
        # conv2d computes a a 2D convolution given
        # - a 4D input tensor (our data)
        # - a 4D filter tensor (our weights)
        # - strides: 1D tensor of length 4
        # - padding
        # This is flattened to a 2D matrix of shape
        # [filter_height * filter_width * in_channels, output_channels]
        conv1 = conv2d(data, 1, layer1_weights, layer1_biases)
        # Let's maxpool to downsample
        pool1 = maxpool2d(conv1, k=2)
     
        conv2 = conv2d(pool1, 1, layer2_weights, layer2_biases)
        pool2 = maxpool2d(conv2, k=2)
    
        # Fully connected layer, we need to reshape our convolution layer output
        # to fit the fully connected layer input
        shape = pool2.get_shape().as_list()
        reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        
        # Apply dropout
        if (apply_dropout):
            hidden = tf.nn.dropout(hidden, 1)
        
        # Our second hidden layer
        hidden2 = tf.nn.relu(tf.matmul(hidden, layer4_weights) + layer4_biases)
    
        # Apply dropout again
        if (apply_dropout):
            hidden2 = tf.nn.dropout(hidden2, 1)

        # Output layer
        return tf.matmul(hidden2, layer5_weights) + layer5_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset, apply_dropout=False))
    test_prediction = tf.nn.softmax(model(tf_test_dataset, apply_dropout=False))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.349648
# Minibatch accuracy: 15.6%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.335564
# Minibatch accuracy: 53.1%
# Validation accuracy: 58.3%
# Minibatch loss at step 100: 1.169590
# Minibatch accuracy: 71.9%
# Validation accuracy: 70.1%
# Minibatch loss at step 150: 0.445541
# Minibatch accuracy: 84.4%
# Validation accuracy: 78.5%
# Minibatch loss at step 200: 0.507983
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 250: 0.766231
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.0%
# Minibatch loss at step 300: 0.455454
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.8%
# Minibatch loss at step 350: 0.768455
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.0%
# Minibatch loss at step 400: 0.657178
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.2%
# Minibatch loss at step 450: 0.828612
# Minibatch accuracy: 71.9%
# Validation accuracy: 82.8%
# Minibatch loss at step 500: 0.512465
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 550: 0.638611
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.2%
# Minibatch loss at step 600: 0.821535
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.3%
# Minibatch loss at step 650: 0.216387
# Minibatch accuracy: 96.9%
# Validation accuracy: 82.7%
# Minibatch loss at step 700: 0.328104
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 750: 0.540366
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.1%
# Minibatch loss at step 800: 0.980424
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 850: 0.455356
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.3%
# Minibatch loss at step 900: 0.395427
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.6%
# Minibatch loss at step 950: 0.470991
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.8%
# Minibatch loss at step 1000: 0.277557
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 1050: 0.184567
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 1100: 0.321986
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.6%
# Minibatch loss at step 1150: 0.572763
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 1200: 0.358614
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.4%
# Minibatch loss at step 1250: 0.705378
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 1300: 0.274717
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.7%
# Minibatch loss at step 1350: 0.275958
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 1400: 0.299582
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.3%
# Minibatch loss at step 1450: 0.622139
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 1500: 0.445688
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 1550: 0.407796
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 1600: 0.234029
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.2%
# Minibatch loss at step 1650: 0.150966
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 1700: 0.460090
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.0%
# Minibatch loss at step 1750: 0.640999
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 1800: 0.292838
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 1850: 0.751925
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.2%
# Minibatch loss at step 1900: 0.343183
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# Minibatch loss at step 1950: 0.566194
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 2000: 0.237840
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 2050: 0.325432
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# Minibatch loss at step 2100: 0.321853
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# Minibatch loss at step 2150: 0.712134
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.0%
# Minibatch loss at step 2200: 1.145364
# Minibatch accuracy: 62.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 2250: 0.471868
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.0%
# Minibatch loss at step 2300: 0.386706
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# Minibatch loss at step 2350: 0.390018
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 2400: 0.289270
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 2450: 0.410402
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.2%
# Minibatch loss at step 2500: 0.841672
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.4%
# Minibatch loss at step 2550: 0.479300
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.0%
# Minibatch loss at step 2600: 0.344119
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.9%
# Minibatch loss at step 2650: 0.507454
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# Minibatch loss at step 2700: 0.589759
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.3%
# Minibatch loss at step 2750: 0.622388
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.0%
# Minibatch loss at step 2800: 0.454414
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.3%
# Minibatch loss at step 2850: 0.679883
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.6%
# Minibatch loss at step 2900: 0.292677
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# Minibatch loss at step 2950: 0.858840
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 3000: 0.143966
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.3%
# Minibatch loss at step 3050: 0.507774
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# Minibatch loss at step 3100: 0.675157
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.7%
# Minibatch loss at step 3150: 0.437656
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.5%
# Minibatch loss at step 3200: 0.103431
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.5%
# Minibatch loss at step 3250: 0.596785
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.2%
# Minibatch loss at step 3300: 0.201069
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.7%
# Minibatch loss at step 3350: 0.268692
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 3400: 0.447157
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# Minibatch loss at step 3450: 0.524243
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.8%
# Minibatch loss at step 3500: 0.447506
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 3550: 0.491005
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# Minibatch loss at step 3600: 0.331247
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 3650: 0.443211
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# Minibatch loss at step 3700: 0.050478
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 3750: 0.263907
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 3800: 0.533493
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 3850: 0.315901
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# Minibatch loss at step 3900: 0.212460
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# Minibatch loss at step 3950: 0.285063
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# Minibatch loss at step 4000: 0.280507
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 4050: 0.291404
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 4100: 0.379668
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 4150: 0.338775
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# Minibatch loss at step 4200: 0.413257
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.3%
# Minibatch loss at step 4250: 0.145565
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.2%
# Minibatch loss at step 4300: 0.228549
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.2%
# Minibatch loss at step 4350: 0.319656
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 4400: 0.364462
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 4450: 0.573402
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.8%
# Minibatch loss at step 4500: 0.199852
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 4550: 0.245397
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 4600: 0.354494
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 4650: 0.668702
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 4700: 0.223985
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 4750: 0.210389
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 4800: 0.174943
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 4850: 0.329701
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 4900: 0.210960
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 4950: 0.527227
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.9%
# Minibatch loss at step 5000: 0.233780
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 5050: 0.420880
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.1%
# Minibatch loss at step 5100: 0.201994
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 5150: 0.193207
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 5200: 0.286667
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 5250: 0.371682
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 5300: 0.469336
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 5350: 0.239851
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# Minibatch loss at step 5400: 0.516192
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.8%
# Minibatch loss at step 5450: 0.346732
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# Minibatch loss at step 5500: 0.180327
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 5550: 0.315659
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 5600: 0.172651
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 5650: 0.279186
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# Minibatch loss at step 5700: 0.361802
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 5750: 0.258905
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 5800: 0.495251
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.9%
# Minibatch loss at step 5850: 0.674695
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.1%
# Minibatch loss at step 5900: 0.278718
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 5950: 0.302845
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 6000: 0.478206
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.1%
# Minibatch loss at step 6050: 0.322827
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.9%
# Minibatch loss at step 6100: 0.398212
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 6150: 0.230955
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 6200: 0.384293
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 6250: 0.420166
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 6300: 0.226482
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 6350: 0.655694
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.3%
# Minibatch loss at step 6400: 0.501646
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# Minibatch loss at step 6450: 0.360002
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 6500: 0.541664
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 6550: 0.173419
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 6600: 0.410503
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.5%
# Minibatch loss at step 6650: 0.193519
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 6700: 0.073728
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 6750: 0.332453
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 6800: 0.165842
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 6850: 0.706547
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.3%
# Minibatch loss at step 6900: 0.422912
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 6950: 0.213391
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 7000: 0.053024
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 7050: 0.483201
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.3%
# Minibatch loss at step 7100: 0.063793
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 7150: 0.180742
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# Minibatch loss at step 7200: 0.618266
# Minibatch accuracy: 71.9%
# Validation accuracy: 89.6%
# Minibatch loss at step 7250: 0.148628
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# Minibatch loss at step 7300: 0.285244
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# Minibatch loss at step 7350: 0.139381
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 7400: 0.089833
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 7450: 0.611106
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 7500: 0.331721
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 7550: 0.166183
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 7600: 0.514319
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.6%
# Minibatch loss at step 7650: 0.147672
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# Minibatch loss at step 7700: 0.261361
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 7750: 0.368101
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 7800: 0.285878
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 7850: 0.337299
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 7900: 0.251524
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 7950: 0.350399
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 8000: 0.204368
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 8050: 0.428448
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 8100: 0.326968
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.3%
# Minibatch loss at step 8150: 0.273253
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 8200: 0.336285
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 8250: 0.405014
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 8300: 0.032803
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 8350: 0.214583
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 8400: 0.439030
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 8450: 0.279703
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 8500: 0.484845
# Minibatch accuracy: 78.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 8550: 0.015021
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 8600: 0.287481
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 8650: 0.225234
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# Minibatch loss at step 8700: 0.448095
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.9%
# Minibatch loss at step 8750: 0.248101
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 8800: 0.432707
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 8850: 0.076250
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# Minibatch loss at step 8900: 0.532852
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 8950: 0.503138
# Minibatch accuracy: 78.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 9000: 0.173020
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 9050: 0.480035
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 9100: 0.073070
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 9150: 0.350348
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 9200: 0.556811
# Minibatch accuracy: 78.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 9250: 0.386953
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 9300: 0.253974
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 9350: 0.437644
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 9400: 0.304856
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# Minibatch loss at step 9450: 0.159512
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 9500: 0.451819
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 9550: 0.273512
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# Minibatch loss at step 9600: 0.368158
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.7%
# Minibatch loss at step 9650: 0.278138
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 9700: 0.289011
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 9750: 0.534696
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 9800: 0.238465
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 9850: 0.127121
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# Minibatch loss at step 9900: 0.167998
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# Minibatch loss at step 9950: 0.371265
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 10000: 0.050071
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# Test accuracy: 95.3%

# %% [markdown]
# We are adding two connected hidden layers at the end (instead of 1) and apply dropout after each fully connected layer. We got to a score of 91.1% which isn't too great yet.
#
# After tuning this however we got to 93.7%! We reduced the patch size to 4x4.
#
# Increasing number of steps and increasing the size of the connected layer we reached 95.3%!
